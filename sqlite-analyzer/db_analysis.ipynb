# %% [markdown]
# # Análisis de Base de Datos SQLite
#
# Este notebook analiza la base de datos SQLite ubicada en:
# `C:\Users\cpascual\PycharmProjects\pythonProject\cursos_actividades\sina\sqlite-analyzer\sqlite-analyzer\src\db\database.sqlite3.db`
#
# Verificaremos:
# 1. La estructura de la base de datos (tablas y columnas)
# 2. Si las tablas contienen información o están vacías
# 3. Proporción de valores NULL en cada tabla/columna

# %%
# Importar librerías necesarias
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Configuración de visualización
plt.style.use('ggplot')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %%
# Definir la ruta a la base de datos
db_path = r"C:\Users\cpascual\PycharmProjects\pythonProject\cursos_actividades\sina\sqlite-analyzer\src\db\database_new.sqlite3.db"

# Verificar que el archivo existe
if os.path.exists(db_path):
    print(f"✅ Base de datos encontrada: {db_path}")
    print(f"Tamaño: {os.path.getsize(db_path) / 1024:.2f} KB")
else:
    print(f"❌ Error: La base de datos no existe en la ruta especificada")
# Out:
# ✅ Base de datos encontrada: C:\Users\cpascual\PycharmProjects\pythonProject\cursos_actividades\sina\sqlite-analyzer\src\db\database_new.sqlite3.db
# Tamaño: 27952.00 KB

# %%
# Conectar a la base de datos
try:
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    print("✅ Conexión exitosa a la base de datos")
except Exception as e:
    print(f"❌ Error al conectar a la base de datos: {e}")
# Out:
# ✅ Conexión exitosa a la base de datos

# %%
# Obtener lista de todas las tablas en la base de datos
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

if tables:
    print(f"Se encontraron {len(tables)} tablas en la base de datos:")
    for i, table in enumerate(tables, 1):
        print(f"  {i}. {table[0]}")
else:
    print("No se encontraron tablas en la base de datos")
# Out:
# Se encontraron 236 tablas en la base de datos:
#   1. ACCI_PATIENT_CONDITIONS
#   2. ACCI_VEHICLE_TYPES
#   3. ACCI_WORKER_TYPES
#   4. ACTI_ACTIVITY_STATES
#   5. ALLE_ALLERGY_CATEGORIES
#   6. ALLE_ALLERGY_END_REASONS
#   7. ALLE_ALLERGY_RESULTS
#   8. ALLE_ALLERGY_SEVERITY_LEVELS
#   9. ALLE_ALLERGY_TYPES
#   10. ALLE_INTOLERANCES
#   11. ALLE_L2_NOT_MED_ALLERGENS
#   12. ALLE_NOT_MEDICINAL_ALLERGENS
#   13. ALLE_UNKNOWN_REASONS
#   14. APPO_ABSENT_REASONS
#   15. APPO_ADMISSION_PREFERENCES
#   16. APPO_ADMISSION_TYPES
#   17. APPO_AMBI_STATES
#   18. APPO_APPOINTMENTS
#   19. APPO_APPOINTMENT_ATTENDANCES
#   20. APPO_CANCELLATION_REASONS
#   21. APPO_FREQUENCY
#   22. APPO_INTERCONSULTATION_REASONS
#   23. APPO_INTERCONSULTATION_SYSTEMS
#   24. APPO_INTER_REJECT_REASON
#   25. APPO_MOBILITIES
#   26. APPO_NOT_ATTENDED_REASONS
#   27. APPO_ORIGIN_TYPES
#   28. APPO_PENDING_REVIEW_REASONS
#   29. APPO_PERIODICS
#   30. APPO_POSTPONED_REASONS
#   31. APPO_PROPOSALS
#   32. APPO_PROPOSAL_STATES
#   33. APPO_PROPOSAL_TYPE_STATES
#   34. APPO_PROP_ATTENTION_TYPES
#   35. APPO_REPETITION_INTERVAL
#   36. APPO_RESCHEDULE_REASONS
#   37. APPO_SESSION_TYPES
#   38. APPO_STATES
#   39. APPO_TYPES
#   40. APPR_ANESTHESIA_STATES
#   41. APPR_CLIN_HIST_CANCEL_REASONS
#   42. APPR_CLIN_HIST_FILE_CATEGORIES
#   43. APPR_CLIN_HIST_FILE_PRIORITIES
#   44. APPR_CLIN_HIST_FILE_REASONS
#   45. APPR_CLIN_HIST_FILE_STATES
#   46. APPR_CLIN_HIST_FILE_TYPES
#   47. APPR_CLIN_HIST_FILE_USES
#   48. APPR_NOT_EXPLORATION_NEXT_ACTIONS
#   49. APPR_TREATMENTS
#   50. APPR_TREATMENT_ACTIONS
#   51. APPR_TREATMENT_DEST_DISCHARGE
#   52. APPR_TREATMENT_DISCHARGE_TYPE
#   53. APPR_TREATMENT_PROGRAMMING_TYPES
#   54. APPR_TREATMENT_STATES
#   55. ARTI_ARTICLES
#   56. ARTI_ARTICLE_TYPES
#   57. BEDS_BEDS
#   58. BEDS_BED_TYPES
#   59. BEDS_CONSTRAINTS
#   60. CARE_CARES
#   61. CLIP_CLINICAL_PROCESSES
#   62. CLIP_STATES
#   63. CODR_CATALOGS
#   64. CODR_CODING_TYPES
#   65. CODR_COMPLEXITY_DEGREE
#   66. CODR_DIAGNOSTIC_GROUPS
#   67. CODR_DIAGNOSTIC_TYPES
#   68. CODR_DIAG_ALERT_TYPES
#   69. CURE_BED_VALUATIONS
#   70. CURE_CLEAN_TYPES
#   71. CURE_DEBRIDEMENT_TYPES
#   72. CURE_DISINFECTION_TYPES
#   73. CURE_DRAINAGE_TYPES
#   74. CURE_EXUDE_AMOUNTS
#   75. CURE_EXUDE_TYPES
#   76. CURE_OINTMENT_TYPES
#   77. CURE_PHASES
#   78. CURE_PRIMARY_DRESSINGS
#   79. CURE_SKIN_VALUATIONS
#   80. CURE_STAPLES_REMOVE_TYPES
#   81. CURE_SURGI_COMPLICA_TYPES
#   82. CURE_TYPES
#   83. DIAG_DIAGNOSTIC_STATES
#   84. DIAG_LATERALITIES
#   85. DOCS_DOCUMENTS
#   86. DOCS_DOCUMENT_TYPES
#   87. DOCS_TYPE_CATEGORIES
#   88. EMER_EMERGENCY_ROOM_RESOURCES
#   89. EPIS_ADMIN_DISCHARGE_REASONS
#   90. EPIS_AMBI_STATES
#   91. EPIS_DESTINATIONS
#   92. EPIS_DIAGNOSTICS
#   93. EPIS_DIET_SHIFTS
#   94. EPIS_DIET_TYPES
#   95. EPIS_DISCHARGE_SHIFTS
#   96. EPIS_EPISODES
#   97. EPIS_ISOLATION_TYPES
#   98. EPIS_MEDICAL_DISCHARGE_REASONS
#   99. EPIS_NOTIFIABLE_DISEASE_DIAGNOSTICS_STATES
#   100. EPIS_NOTIFIABLE_DISEASE_ORIGIN
#   101. EPIS_PROCEDURES
#   102. EPIS_STATES
#   103. EXPL_DESCRIPTIONS
#   104. EXPL_IMAGE_TYPES
#   105. HACR_CRITERIA_RISKS
#   106. HADT_DIABETES_TYPES
#   107. HAHT_HYPERTENSION_TYPES
#   108. HAIR_INDICATORS_RESULTS
#   109. HAIT_INDICATOR_TYPES
#   110. HEAL_CONTROLS
#   111. HEAL_DIABETES_INDICATORS
#   112. HEAL_HEALTHY_TYPES
#   113. HEAL_HYPERTENS_INDICATORS
#   114. HIST_ALCOHOL_TYPES
#   115. HIST_ANDROLOGICALS
#   116. HIST_BIRTH_TYPES
#   117. HIST_CONTRACEPTIVE_METHODS
#   118. HIST_GYNECOBSTETRICS
#   119. HIST_HISTORY_DIAG_PROC
#   120. HIST_HISTORY_TYPES
#   121. HIST_MORPHOLOGICAL_TYPES
#   122. HIST_OTOACOUSTIC_TYPES
#   123. HIST_PEDIATRICS
#   124. HIST_SOCIOECONOMICS
#   125. HIST_SPORT_LEVELS
#   126. HIST_SPORT_TYPES
#   127. HIST_TOXIC_HABITS
#   128. I18N_LANGUAGES
#   129. INJU_BURN_STAGES
#   130. INJU_LOCATIONS
#   131. INJU_NEOPLA_STAGES
#   132. INJU_PRESSURE_STAGES
#   133. INJU_SURGICAL_STAGES
#   134. INJU_TYPES
#   135. INTE_EXTERNAL_ACTIVITY
#   136. INVASIVE_DEVICES
#   137. INVASIVE_DEVICES_SUBTYPES
#   138. INVASIVE_DEVICES_TYPES
#   139. MEDI_ACTIVE_INGREDIENTS
#   140. MEDI_GROUPS
#   141. MEDI_LABORATORIES
#   142. MEDI_MEDICATIONS
#   143. MEDI_PHARMACEUTICAL_FORMS
#   144. MEDI_PHARMA_THERAPEUTIC_GROUPS
#   145. MEDI_ROUTES
#   146. NURSING_INTERVENTIONS_TYPES
#   147. ONCO_BIOPSY_TYPES
#   148. ONCO_CANCERS
#   149. ONCO_CLINICAL_STATUS
#   150. ONCO_DIFFERENTIATION_STAGES
#   151. ONCO_DISEASE_STATES
#   152. ONCO_EPITHELIAL
#   153. ONCO_EVENT_INDICATIONS
#   154. ONCO_FAMILIAR_HISTORY
#   155. ONCO_GYN_HISTOLOGIES
#   156. ONCO_GYN_HRD_STATUS
#   157. ONCO_GYN_TYPES
#   158. ONCO_HISTOLOGICAL_TYPES
#   159. ONCO_HISTOLOGICS_TYPES
#   160. ONCO_HISTOLOGIES
#   161. ONCO_HORMONOTHERAPY_GUIDELINES
#   162. ONCO_INTERVENTION_EVENTS
#   163. ONCO_IRRADIATION_METHODS
#   164. ONCO_KIDNEY_TYPES
#   165. ONCO_LUNG_DISEASE_EXTS
#   166. ONCO_LUNG_TYPES
#   167. ONCO_LYMPHOM_TYPES
#   168. ONCO_MARKERS_RESULTS
#   169. ONCO_PATIENT_STATES
#   170. ONCO_PROGNOSIS
#   171. ONCO_RADIOTHERAPY_TYPES
#   172. ONCO_RECIST_CRITERION
#   173. ONCO_SARCOMA_TYPES
#   174. ONCO_STATES
#   175. ONCO_SURGERY_GUIDELINES
#   176. ONCO_TRANSPLANT_TYPES
#   177. ONCO_TUMOR_FOCALITIES
#   178. ONCO_TUMOR_LATERALITY_TYPES
#   179. ONCO_TUMOR_LOCALIZATIONS
#   180. ONCO_TUMOR_MARKERS
#   181. ONCO_TUMOR_PHASES
#   182. ORMA_APPLICATIONS
#   183. ORMA_BENEFIT_TYPES
#   184. ORMA_LABORATORIES
#   185. ORMA_RESOURCE_TYPES
#   186. ORMA_UNITS
#   187. PARA_BLOOD_GROUPS
#   188. PARA_GENDERS
#   189. PARA_HEALTH_ID_TYPES
#   190. PARA_IDENTIFICATION_TYPES
#   191. PARA_MEASUREMENT_UNITS
#   192. PARA_MEASURE_UNIT_TYPES
#   193. PARA_PRIORITY_TYPES
#   194. PATI_MERGE_PATIENTS
#   195. PATI_ORIGIN_PROFESSIONALS
#   196. PATI_PATIENTS
#   197. PATI_PATIENT_ADDRESSES
#   198. PATI_PATIENT_ALLERGIES
#   199. PATI_PATIENT_CONTACTS
#   200. PATI_PATIENT_CONTACT_PERSONS
#   201. PATI_PATIENT_HEALTH_IDS
#   202. PATI_PATIENT_IDENTIFICATIONS
#   203. PATI_PATIENT_PHONES
#   204. PATI_PATIENT_TYPES
#   205. PATI_USUAL_MEDICATION
#   206. PROC_PROCEDURES
#   207. PROC_PROCEDURE_TYPES
#   208. PROC_PROCEDURE_VIEW_TYPES
#   209. PROC_RAYS_STUDIO_TYPE
#   210. PROC_SURGICAL_DESTINATIONS
#   211. PROC_SURGICAL_TIMES
#   212. PROP_PROPOSAL_REASONS
#   213. PROP_PROPOSAL_TYPES
#   214. PROP_RADIO_PRESENCE_TYPES
#   215. PROP_SEDATION_TYPES
#   216. PROP_TYPE_SAMPLE_TYPES
#   217. SCRE_PSA_RESULTS
#   218. SCRE_RECTAL_EXAMINATION_ASYMMETRIES
#   219. SCRE_RECTAL_EXAMINATION_RESULTS
#   220. SCRE_SCREENING_EXCLUSION_REASONS
#   221. SCRE_SCREENING_INCLUSION_REASONS
#   222. SURG_ANESTHESIA_RISKS
#   223. SURG_ANESTHESIA_TYPES
#   224. SURG_ANESTHESIA_VALORATIONS
#   225. SURG_INTERVENTION_TYPES
#   226. TEST_PROFILES
#   227. TEST_STATES
#   228. TEST_TESTS
#   229. TEST_TEST_SUBTYPES
#   230. TEST_TEST_TYPES
#   231. TIME_LINE_VIEW_TYPES
#   232. TRIA_REASONS
#   233. TRIA_SYMPTOMS
#   234. VACC_VACCINES
#   235. _METACOLS
#   236. _DICTIONARIES

# %% [markdown]
# ## Análisis de Estructura y Contenido de Tablas
#
# A continuación, analizaremos cada tabla para verificar:
# 1. Su esquema (columnas y tipos de datos)
# 2. Conteo total de registros
# 3. Porcentaje de valores NULL por columna
# 4. Muestra de datos (primeras 5 filas)

# %%
# Función para analizar una tabla
def analyze_table(table_name):
    print(f"\n{'='*80}")
    print(f"ANÁLISIS DE TABLA: {table_name}")
    print(f"{'='*80}")
    
    # Obtener esquema de la tabla
    cursor.execute(f"PRAGMA table_info({table_name})")
    columns_info = cursor.fetchall()
    
    print("Estructura de la tabla:")
    print(f"{'Columna':<30} {'Tipo':<15} {'Nullable':<8} {'PK':<5}")
    print(f"{'-'*30} {'-'*15} {'-'*8} {'-'*5}")
    for col in columns_info:
        # col = (id, name, type, notnull, default_value, pk)
        print(f"{col[1]:<30} {col[2]:<15} {'No' if col[3] else 'Sí':<8} {'Sí' if col[5] else 'No':<5}")
    
    # Contar registros
    cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
    count = cursor.fetchone()[0]
    
    if count == 0:
        print(f"\n⚠️ La tabla {table_name} está vacía (0 registros)")
        return
    
    print(f"\nNúmero total de registros: {count}")
    
    # Calcular porcentaje de NULL por columna
    null_stats = {}
    for col in columns_info:
        col_name = col[1]
        cursor.execute(f"SELECT COUNT(*) FROM {table_name} WHERE {col_name} IS NULL")
        null_count = cursor.fetchone()[0]
        null_percentage = (null_count / count) * 100
        null_stats[col_name] = {
            'total': count,
            'null_count': null_count,
            'null_percentage': null_percentage
        }
    
    # Mostrar estadísticas de NULL
    print("\nEstadísticas de valores NULL:")
    print(f"{'Columna':<30} {'Total NULLs':<15} {'% NULLs':<10}")
    print(f"{'-'*30} {'-'*15} {'-'*10}")
    for col, stats in null_stats.items():
        print(f"{col:<30} {stats['null_count']:<15} {stats['null_percentage']:.2f}%")
    
    # Obtener una muestra de datos y mostrar información ampliada
    try:
        # Cargar todos los datos para análisis estadístico pero limitar a 1000 filas para evitar problemas de memoria
        df_full = pd.read_sql_query(f"SELECT * FROM {table_name} LIMIT 1000", conn)
        df = df_full.head(5)  # Primeras 5 filas para la muestra
        
        print("\nMuestra de datos (primeras 5 filas):")
        print(df)
        
        # Verificar si todos los datos son NULL
        if df_full.isnull().all().all():
            print("⚠️ ADVERTENCIA: Todos los valores en la muestra son NULL")
            return
            
        # Mostrar estadísticas descriptivas básicas
        print("\nEstadísticas descriptivas:")
        
        # Para cada columna, mostrar estadísticas específicas según su tipo
        for col_name in df_full.columns:
            print(f"\n- Columna: {col_name}")
            
            # Detectar el tipo de columna
            if df_full[col_name].dtype.kind in 'iuf':  # Integer, Unsigned Integer, Float
                print(f"  Tipo: Numérico ({df_full[col_name].dtype})")
                print(f"  Mínimo: {df_full[col_name].min()}")
                print(f"  Máximo: {df_full[col_name].max()}")
                print(f"  Media: {df_full[col_name].mean():.2f}")
                print(f"  Mediana: {df_full[col_name].median()}")
                
                # Mostrar distribución de valores si hay menos de 10 valores distintos
                value_counts = df_full[col_name].value_counts().head(5)
                if len(value_counts) <= 10:
                    print(f"  Distribución de valores:")
                    for val, count in value_counts.items():
                        print(f"    {val}: {count} registros ({count/len(df_full)*100:.2f}%)")
            
            # Para columnas de texto
            elif df_full[col_name].dtype == 'object':
                print(f"  Tipo: Texto/Objeto ({df_full[col_name].dtype})")
                
                # Contar valores únicos
                unique_count = df_full[col_name].nunique()
                print(f"  Valores únicos: {unique_count}")
                
                # Si hay pocos valores únicos, mostrarlos todos (hasta 10)
                if 1 < unique_count <= 10:
                    value_counts = df_full[col_name].value_counts()
                    print(f"  Distribución de valores:")
                    for val, count in value_counts.items():
                        print(f"    {val}: {count} registros ({count/len(df_full)*100:.2f}%)")
                
                # Para muchos valores únicos, mostrar solo los más frecuentes
                elif unique_count > 10:
                    top_values = df_full[col_name].value_counts().head(5)
                    print(f"  Valores más frecuentes:")
                    for val, count in top_values.items():
                        print(f"    {val}: {count} registros ({count/len(df_full)*100:.2f}%)")
                
                # Mostrar longitud media del texto si los valores son strings
                non_null = df_full[col_name].dropna()
                if non_null.shape[0] > 0 and all(isinstance(x, str) for x in non_null.head(5)):
                    avg_len = non_null.str.len().mean()
                    print(f"  Longitud media: {avg_len:.2f} caracteres")
            
            # Para fechas
            elif pd.api.types.is_datetime64_any_dtype(df_full[col_name]):
                print(f"  Tipo: Fecha/Hora ({df_full[col_name].dtype})")
                if df_full[col_name].count() > 0:
                    print(f"  Fecha más antigua: {df_full[col_name].min()}")
                    print(f"  Fecha más reciente: {df_full[col_name].max()}")
                    # Mostrar distribución por año si hay variedad de años
                    years = df_full[col_name].dt.year.value_counts().head(5)
                    if len(years) > 1:
                        print(f"  Distribución por año:")
                        for year, count in years.items():
                            print(f"    {year}: {count} registros ({count/len(df_full)*100:.2f}%)")
            
            # Para otros tipos
            else:
                print(f"  Tipo: Otro ({df_full[col_name].dtype})")
                print(f"  Valores únicos: {df_full[col_name].nunique()}")
        
        # Analizar relaciones con otras tablas si hay columnas con '_ID' que podrían ser claves foráneas
        fk_columns = [col for col in df_full.columns if '_ID' in col and col != f"{table_name.split('_')[0]}_ID"]
        if fk_columns:
            print("\nPosibles relaciones con otras tablas:")
            for fk_col in fk_columns:
                # Detectar tabla relacionada por el prefijo
                prefix = fk_col.split('_')[0]
                related_tables = [t[0] for t in tables if t[0].startswith(prefix)]
                
                if related_tables:
                    print(f"  Columna {fk_col} puede relacionarse con: {', '.join(related_tables)}")
                    
                    # Mostrar los valores más comunes de esta FK
                    top_fk_values = df_full[fk_col].value_counts().head(3)
                    if not top_fk_values.empty:
                        print(f"  Valores más comunes de {fk_col}:")
                        for val, count in top_fk_values.items():
                            print(f"    {val}: {count} registros ({count/len(df_full)*100:.2f}%)")
        
    except Exception as e:
        print(f"Error al obtener datos extendidos: {e}")

# %%
# Analizar cada tabla en la base de datos
for table in tables:
    analyze_table(table[0])
# Out:
# ================================================================================
# ANÁLISIS DE TABLA: ACCI_PATIENT_CONDITIONS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# APCO_ID                        tinyint         Sí       Sí
# APCO_DELETED                   bit             Sí       No
# APCO_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 6
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# APCO_ID                        0               0.00%
# APCO_DELETED                   0               0.00%
# APCO_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    APCO_ID  APCO_DELETED APCO_DESCRIPTION_ES                       MTIME
# 0        1             0           Conductor  2000-11-30 23:30:55.123456
# 1        2             0            Ocupante  2000-11-30 23:30:55.123456
# 2        3             0              Peatón  2000-11-30 23:30:55.123456
# 3        4             0            Ciclista  2000-11-30 23:30:55.123456
# 4        5             0          Motorista   2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: ACCI_VEHICLE_TYPES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# VETY_ID                        tinyint         Sí       Sí
# VETY_DESCRIPTION_ES            nvarchar        Sí       No
# VETY_DELETED                   bit             Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 8
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# VETY_ID                        0               0.00%
# VETY_DESCRIPTION_ES            0               0.00%
# VETY_DELETED                   0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    VETY_ID VETY_DESCRIPTION_ES  VETY_DELETED                       MTIME
# 0        1          Ciclomotor             0  2000-11-30 23:30:55.123456
# 1        2                Quad             0  2000-11-30 23:30:55.123456
# 2        3         Motocicleta             0  2000-11-30 23:30:55.123456
# 3        4               Coche             0  2000-11-30 23:30:55.123456
# 4        5              Camión             0  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: ACCI_WORKER_TYPES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# WOTY_ID                        tinyint         Sí       Sí
# WOTY_DELETED                   bit             Sí       No
# WOTY_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 3
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# WOTY_ID                        0               0.00%
# WOTY_DELETED                   0               0.00%
# WOTY_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    WOTY_ID  WOTY_DELETED WOTY_DESCRIPTION_ES                       MTIME
# 0        1             0            Autónomo  2000-11-30 23:30:55.123456
# 1        2             0    Por Cuenta Ajena  2000-11-30 23:30:55.123456
# 2        3             0        En prácticas  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: ACTI_ACTIVITY_STATES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# ACST_ID                        tinyint         Sí       Sí
# ACST_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 6
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# ACST_ID                        0               0.00%
# ACST_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    ACST_ID ACST_DESCRIPTION_ES                       MTIME
# 0        1              Creada  2000-11-30 23:30:55.123456
# 1        2           Realizada  2000-11-30 23:30:55.123456
# 2        3        No procesada  2000-11-30 23:30:55.123456
# 3        4           Facturada  2000-11-30 23:30:55.123456
# 4        5           Procesada  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: ALLE_ALLERGY_CATEGORIES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# ALCA_ID                        tinyint         Sí       Sí
# ALCA_DELETED                   bit             Sí       No
# ALCA_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 2
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# ALCA_ID                        0               0.00%
# ALCA_DELETED                   0               0.00%
# ALCA_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    ALCA_ID  ALCA_DELETED ALCA_DESCRIPTION_ES                       MTIME
# 0        1             0       Medicamentosa  2000-11-30 23:30:55.123456
# 1        2             0    No medicamentosa  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: ALLE_ALLERGY_END_REASONS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# ALER_ID                        tinyint         Sí       Sí
# ALER_DELETED                   bit             Sí       No
# ALER_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 3
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# ALER_ID                        0               0.00%
# ALER_DELETED                   0               0.00%
# ALER_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    ALER_ID  ALER_DELETED   ALER_DESCRIPTION_ES                       MTIME
# 0        1             0  Error administrativo  2000-11-30 23:30:55.123456
# 1        2             0                Idioma  2000-11-30 23:30:55.123456
# 2        3             1       Prueba Juanfran  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: ALLE_ALLERGY_RESULTS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# ALRE_ID                        tinyint         Sí       Sí
# ALRE_DELETED                   bit             Sí       No
# ALRE_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 3
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# ALRE_ID                        0               0.00%
# ALRE_DELETED                   0               0.00%
# ALRE_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    ALRE_ID  ALRE_DELETED ALRE_DESCRIPTION_ES                       MTIME
# 0        1             0               Tiene  2000-11-30 23:30:55.123456
# 1        2             0          No refiere  2000-11-30 23:30:55.123456
# 2        3             0        Se desconoce  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: ALLE_ALLERGY_SEVERITY_LEVELS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# ALSE_ID                        tinyint         Sí       Sí
# ALSE_DELETED                   bit             Sí       No
# ALSE_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 3
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# ALSE_ID                        0               0.00%
# ALSE_DELETED                   0               0.00%
# ALSE_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    ALSE_ID  ALSE_DELETED ALSE_DESCRIPTION_ES                       MTIME
# 0        1             0            Muy alta  2000-11-30 23:30:55.123456
# 1        2             0                Alta  2000-11-30 23:30:55.123456
# 2        3             0                Leve  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: ALLE_ALLERGY_TYPES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# ALTY_ID                        tinyint         Sí       Sí
# ALTY_DELETED                   bit             Sí       No
# ALTY_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 2
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# ALTY_ID                        0               0.00%
# ALTY_DELETED                   0               0.00%
# ALTY_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    ALTY_ID  ALTY_DELETED ALTY_DESCRIPTION_ES                       MTIME
# 0        1             0             Alergia  2000-11-30 23:30:55.123456
# 1        2             0        Intolerancia  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: ALLE_INTOLERANCES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# ALIN_ID                        INT             Sí       Sí
# ALIN_DELETED                   bit             Sí       No
# ALIN_DESCRIPTION_ES            nvarchar        Sí       No
# ALSE_ID                        tinyint         Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 5
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# ALIN_ID                        0               0.00%
# ALIN_DELETED                   0               0.00%
# ALIN_DESCRIPTION_ES            0               0.00%
# ALSE_ID                        0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    ALIN_ID  ALIN_DELETED ALIN_DESCRIPTION_ES  ALSE_ID  \
# 0        1             0             Lactosa        1
# 1        2             0              Gluten        2
# 2        3             0            Fructosa        3
# 3        4             0           Histamina        3
# 4        6             0               Otros        2
#
#                         MTIME
# 0  2000-11-30 23:30:55.123456
# 1  2000-11-30 23:30:55.123456
# 2  2000-11-30 23:30:55.123456
# 3  2000-11-30 23:30:55.123456
# 4  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: ALLE_L2_NOT_MED_ALLERGENS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# LNMA_ID                        INT             Sí       Sí
# LNMA_DELETED                   bit             Sí       No
# LNMA_DESCRIPTION_ES            nvarchar        Sí       No
# ALSE_ID                        tinyint         Sí       No
# NMAL_ID                        INT             Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 17
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# LNMA_ID                        0               0.00%
# LNMA_DELETED                   0               0.00%
# LNMA_DESCRIPTION_ES            0               0.00%
# ALSE_ID                        0               0.00%
# NMAL_ID                        0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    LNMA_ID  LNMA_DELETED LNMA_DESCRIPTION_ES  ALSE_ID  NMAL_ID  \
# 0        1             0             Lactosa        1        1
# 1        2             0              Gluten        1        1
# 2        3             0            Sacarosa        3        1
# 3        4             0            Fructosa        1        1
# 4        5             0               Huevo        3        1
#
#                         MTIME
# 0  2000-11-30 23:30:55.123456
# 1  2000-11-30 23:30:55.123456
# 2  2000-11-30 23:30:55.123456
# 3  2000-11-30 23:30:55.123456
# 4  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: ALLE_NOT_MEDICINAL_ALLERGENS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# NMAL_ID                        INT             Sí       Sí
# NMAL_DELETED                   bit             Sí       No
# NMAL_DESCRIPTION_ES            nvarchar        Sí       No
# ALSE_ID                        tinyint         Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 2
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# NMAL_ID                        0               0.00%
# NMAL_DELETED                   0               0.00%
# NMAL_DESCRIPTION_ES            0               0.00%
# ALSE_ID                        2               100.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    NMAL_ID  NMAL_DELETED NMAL_DESCRIPTION_ES ALSE_ID  \
# 0        1             0           Alimentos    None
# 1        2             0               Otros    None
#
#                         MTIME
# 0  2000-11-30 23:30:55.123456
# 1  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: ALLE_UNKNOWN_REASONS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# ALUR_ID                        tinyint         Sí       Sí
# ALUR_DELETED                   bit             Sí       No
# ALUR_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 3
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# ALUR_ID                        0               0.00%
# ALUR_DELETED                   0               0.00%
# ALUR_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    ALUR_ID  ALUR_DELETED    ALUR_DESCRIPTION_ES                       MTIME
# 0        1             0  Paciente inconsciente  2000-11-30 23:30:55.123456
# 1        2             0                 Idioma  2000-11-30 23:30:55.123456
# 2        3             0                  Ebrio  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_ABSENT_REASONS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# AARE_ID                        INT             Sí       Sí
# AARE_DELETED                   bit             Sí       No
# AARE_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 3
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# AARE_ID                        0               0.00%
# AARE_DELETED                   0               0.00%
# AARE_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    AARE_ID  AARE_DELETED AARE_DESCRIPTION_ES                       MTIME
# 0        1             0             Ausente  2000-11-30 23:30:55.123456
# 1        2             0         Justificada  2000-11-30 23:30:55.123456
# 2        3             0      No justificada  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_ADMISSION_PREFERENCES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# ADPR_ID                        INT             Sí       Sí
# ADPR_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 4
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# ADPR_ID                        0               0.00%
# ADPR_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    ADPR_ID              ADPR_DESCRIPTION_ES                       MTIME
# 0        1      Máxima preferencia (< 48 h)  2000-11-30 23:30:55.123456
# 1        2        Preferencia I (< 15 días)  2000-11-30 23:30:55.123456
# 2        3       Preferencia II (< 2 meses)  2000-11-30 23:30:55.123456
# 3        4  Preferencia III (hasta 4 meses)  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_ADMISSION_TYPES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# ADMT_ID                        INT             Sí       Sí
# ADMT_DELETED                   bit             Sí       No
# ADMT_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 10
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# ADMT_ID                        0               0.00%
# ADMT_DELETED                   0               0.00%
# ADMT_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    ADMT_ID  ADMT_DELETED      ADMT_DESCRIPTION_ES                       MTIME
# 0        1             0                  Urgente  2000-11-30 23:30:55.123456
# 1        2             0               Programado  2000-11-30 23:30:55.123456
# 2        3             0     Intervención urgente  2000-11-30 23:30:55.123456
# 3        4             0  Intervención programada  2000-11-30 23:30:55.123456
# 4        5             0                 Traslado  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_AMBI_STATES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# APAS_ID                        smallint        Sí       Sí
# STAT_ID                        tinyint         Sí       No
# APAS_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 12
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# APAS_ID                        0               0.00%
# STAT_ID                        0               0.00%
# APAS_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    APAS_ID  STAT_ID APAS_DESCRIPTION_ES                       MTIME
# 0        1        1          Programado  2000-11-30 23:30:55.123456
# 1        2        3            En curso  2000-11-30 23:30:55.123456
# 2        3        4          Finalizado  2000-11-30 23:30:55.123456
# 3        4        8           Cancelado  2000-11-30 23:30:55.123456
# 4        5       13        No realizado  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_APPOINTMENTS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# APPO_ID                        bigint          Sí       Sí
# PATI_ID                        INT             Sí       No
# APPO_START_DATE                datetime2       Sí       No
# APPO_END_DATE                  datetime2       Sí       No
# APPO_CREATION_DATE             datetime2       Sí       No
# ORIT_ID                        tinyint         Sí       No
# STAT_ID                        tinyint         Sí       No
# PRRE_ID                        tinyint         Sí       No
# APPR_ID                        bigint          Sí       No
# APPO_OBSERVATIONS              nvarchar        Sí       No
# APPO_JC_START_PATIENT_CARE     datetime2       Sí       No
# APPO_JC_FINISH_PATIENT_CARE    datetime2       Sí       No
# EPIS_ID_CREATED                bigint          Sí       No
# EPIS_ID_ORIGIN                 bigint          Sí       No
# APTY_ID                        tinyint         Sí       No
# CARE_ID                        tinyint         Sí       No
# CENT_ID                        INT             Sí       No
# SERV_ID                        smallint        Sí       No
# UNIT_ID                        smallint        Sí       No
# APPO_OTHER_ABSENT_REASON       nvarchar        Sí       No
# APPO_IS_TELECONSULTATION       bit             Sí       No
# ARER_ID                        INT             Sí       No
# AARE_ID                        INT             Sí       No
# ANAR_ID                        smallint        Sí       No
# STAP_ID                        tinyint         Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 11080
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# APPO_ID                        0               0.00%
# PATI_ID                        0               0.00%
# APPO_START_DATE                0               0.00%
# APPO_END_DATE                  0               0.00%
# APPO_CREATION_DATE             0               0.00%
# ORIT_ID                        0               0.00%
# STAT_ID                        0               0.00%
# PRRE_ID                        2018            18.21%
# APPR_ID                        0               0.00%
# APPO_OBSERVATIONS              6549            59.11%
# APPO_JC_START_PATIENT_CARE     3872            34.95%
# APPO_JC_FINISH_PATIENT_CARE    3852            34.77%
# EPIS_ID_CREATED                8554            77.20%
# EPIS_ID_ORIGIN                 2646            23.88%
# APTY_ID                        0               0.00%
# CARE_ID                        10054           90.74%
# CENT_ID                        0               0.00%
# SERV_ID                        0               0.00%
# UNIT_ID                        11080           100.00%
# APPO_OTHER_ABSENT_REASON       11063           99.85%
# APPO_IS_TELECONSULTATION       0               0.00%
# ARER_ID                        11080           100.00%
# AARE_ID                        11080           100.00%
# ANAR_ID                        11080           100.00%
# STAP_ID                        11080           100.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    APPO_ID  PATI_ID      APPO_START_DATE        APPO_END_DATE  \
# 0      294     3049  2020-06-10 13:30:00  2020-06-10 13:50:00
# 1      328     3700  2020-06-11 12:30:00  2020-06-11 12:50:00
# 2      389     3953  2020-06-11 13:00:00  2020-06-11 13:15:00
# 3      671     3049  2020-06-18 12:30:00  2020-06-18 12:50:00
# 4      737     1997  2020-06-16 14:30:00  2020-06-16 15:00:00
#
#            APPO_CREATION_DATE  ORIT_ID  STAT_ID  PRRE_ID  APPR_ID  \
# 0  2020-06-09 11:47:43.463000        2        8        9    30444
# 1  2020-06-09 12:41:09.477000        2        4        9    30483
# 2  2020-06-09 14:06:59.087000        2        4        9    30547
# 3  2020-06-11 09:09:03.373000        2        4        9    30910
# 4  2020-06-11 12:43:52.782000        2        8        9    30994
#
#   APPO_OBSERVATIONS  APPO_JC_START_PATIENT_CARE APPO_JC_FINISH_PATIENT_CARE  \
# 0              None                        None                        None
# 1              None  2020-06-11 12:35:04.770000  2020-06-11 13:00:34.737000
# 2              None  2020-06-11 13:12:54.180000  2020-06-11 13:34:08.359000
# 3           lou lab  2020-06-18 13:00:29.471000  2020-06-18 13:01:42.250000
# 4               MOV                        None                        None
#
#    EPIS_ID_CREATED EPIS_ID_ORIGIN  APTY_ID  CARE_ID  CENT_ID  SERV_ID UNIT_ID  \
# 0            30378           None        1     10.0        5       30    None
# 1            30413           None        1      NaN        5       30    None
# 2            30475           None        1      NaN        5       11    None
# 3            30758           None        1      NaN        5       30    None
# 4            30826           None        1      7.0        5       30    None
#
#   APPO_OTHER_ABSENT_REASON  APPO_IS_TELECONSULTATION ARER_ID AARE_ID ANAR_ID  \
# 0                     None                         0    None    None    None
# 1                     None                         0    None    None    None
# 2                     None                         0    None    None    None
# 3                     None                         0    None    None    None
# 4                     None                         0    None    None    None
#
#   STAP_ID                       MTIME
# 0    None  2000-11-30 23:30:55.123456
# 1    None  2000-11-30 23:30:55.123456
# 2    None  2000-11-30 23:30:55.123456
# 3    None  2000-11-30 23:30:55.123456
# 4    None  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_APPOINTMENT_ATTENDANCES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# APAT_ID                        tinyint         Sí       Sí
# APAT_DELETED                   bit             Sí       No
# APAT_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 2
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# APAT_ID                        0               0.00%
# APAT_DELETED                   0               0.00%
# APAT_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    APAT_ID  APAT_DELETED APAT_DESCRIPTION_ES                       MTIME
# 0        1             0              Asiste  2000-11-30 23:30:55.123456
# 1        2             0           No asiste  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_CANCELLATION_REASONS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# CARE_ID                        tinyint         Sí       Sí
# CARE_DELETED                   bit             Sí       No
# CARE_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 17
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# CARE_ID                        0               0.00%
# CARE_DELETED                   0               0.00%
# CARE_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    CARE_ID  CARE_DELETED                         CARE_DESCRIPTION_ES  \
# 0        1             0                     Atendido en otro centro
# 1        2             0  Cambio de Día/Hora a peticion del paciente
# 2        3             0           Cancelación  por avería de equipo
# 3        4             0                  Fallecimiento del paciente
# 4        5             0                               Otros Motivos
#
#                         MTIME
# 0  2000-11-30 23:30:55.123456
# 1  2000-11-30 23:30:55.123456
# 2  2000-11-30 23:30:55.123456
# 3  2000-11-30 23:30:55.123456
# 4  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_FREQUENCY
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# FREQ_ID                        tinyint         Sí       Sí
# FREQ_DELETED                   bit             Sí       No
# FREQ_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 3
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# FREQ_ID                        0               0.00%
# FREQ_DELETED                   0               0.00%
# FREQ_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    FREQ_ID  FREQ_DELETED FREQ_DESCRIPTION_ES                       MTIME
# 0        1             0                Días  2000-11-30 23:30:55.123456
# 1        2             0             Semanas  2000-11-30 23:30:55.123456
# 2        3             0               Meses  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_INTERCONSULTATION_REASONS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# INRE_ID                        tinyint         Sí       Sí
# INRE_DELETED                   bit             Sí       No
# INRE_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 4
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# INRE_ID                        0               0.00%
# INRE_DELETED                   0               0.00%
# INRE_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    INRE_ID  INRE_DELETED       INRE_DESCRIPTION_ES                       MTIME
# 0        1             0  Confirmación diagnóstica  2000-11-30 23:30:55.123456
# 1        2             0      Realizar tratamiento  2000-11-30 23:30:55.123456
# 2        3             0               Seguimiento  2000-11-30 23:30:55.123456
# 3        4             0   Control de Especialidad  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_INTERCONSULTATION_SYSTEMS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# INSY_ID                        tinyint         Sí       Sí
# INSY_DELETED                   bit             Sí       No
# INSY_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 3
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# INSY_ID                        0               0.00%
# INSY_DELETED                   0               0.00%
# INSY_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    INSY_ID  INSY_DELETED  INSY_DESCRIPTION_ES                       MTIME
# 0        0             0            SIC Local  2000-11-30 23:30:55.123456
# 1        1             0     Derivación Rayen  2000-11-30 23:30:55.123456
# 2        2             0  Derivación Florence  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_INTER_REJECT_REASON
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# AIRR_ID                        INT             Sí       Sí
# AIRR_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 10
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# AIRR_ID                        0               0.00%
# AIRR_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    AIRR_ID     AIRR_DESCRIPTION_ES                       MTIME
# 0        1               Defunción  2000-11-30 23:30:55.123456
# 1        2    Detectada duplicidad  2000-11-30 23:30:55.123456
# 2        3  Error de transcripción  2000-11-30 23:30:55.123456
# 3        4    El paciente no acude  2000-11-30 23:30:55.123456
# 4        5            Ilocalizable  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_MOBILITIES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# MOBI_ID                        tinyint         Sí       Sí
# MOBI_DESCRIPTION_ES            nvarchar        Sí       No
# MOBI_DELETED                   bit             Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 5
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# MOBI_ID                        0               0.00%
# MOBI_DESCRIPTION_ES            0               0.00%
# MOBI_DELETED                   0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    MOBI_ID   MOBI_DESCRIPTION_ES  MOBI_DELETED                       MTIME
# 0        1                 A pie             0  2000-11-30 23:30:55.123456
# 1        2               En cama             0  2000-11-30 23:30:55.123456
# 2        3   En cama con oxígeno             0  2000-11-30 23:30:55.123456
# 3        4              En silla             0  2000-11-30 23:30:55.123456
# 4        5  En silla con oxígeno             0  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_NOT_ATTENDED_REASONS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# ANAR_ID                        smallint        Sí       Sí
# ANAR_DELETED                   bit             Sí       No
# ANAR_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 11
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# ANAR_ID                        0               0.00%
# ANAR_DELETED                   0               0.00%
# ANAR_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    ANAR_ID  ANAR_DELETED                        ANAR_DESCRIPTION_ES  \
# 0        1             0  Renuncia o rechazo voluntario del usuario
# 1        2             0              Recitado por solicitud médica
# 2        3             0                     Por causa del paciente
# 3        4             0                  Paro de usuarios internos
# 4        5             0     Paciente mal citado en la especialidad
#
#                         MTIME
# 0  2000-11-30 23:30:55.123456
# 1  2000-11-30 23:30:55.123456
# 2  2000-11-30 23:30:55.123456
# 3  2000-11-30 23:30:55.123456
# 4  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_ORIGIN_TYPES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# ORIT_ID                        tinyint         Sí       Sí
# ORIT_DELETED                   bit             Sí       No
# ORIT_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 4
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# ORIT_ID                        0               0.00%
# ORIT_DELETED                   0               0.00%
# ORIT_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    ORIT_ID  ORIT_DELETED ORIT_DESCRIPTION_ES                       MTIME
# 0        1             0          Telefónica  2000-11-30 23:30:55.123456
# 1        2             0       Asistente web  2000-11-30 23:30:55.123456
# 2        3             0            Admisión  2000-11-30 23:30:55.123456
# 3        4             0            Consulta  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_PENDING_REVIEW_REASONS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# APRR_ID                        bigint          Sí       Sí
# APRR_DELETED                   bit             Sí       No
# APRR_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 1
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# APRR_ID                        0               0.00%
# APRR_DELETED                   0               0.00%
# APRR_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    APRR_ID  APRR_DELETED                     APRR_DESCRIPTION_ES  \
# 0        1             0  Prueba solicitada pendiente de revisar
#
#                         MTIME
# 0  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_PERIODICS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# APPE_ID                        bigint          Sí       Sí
# APPE_REPETITIONS               bigint          Sí       No
# APPE_FREQUENCY_NUMBER          INT             Sí       No
# FREQ_ID                        tinyint         Sí       No
# REIN_ID                        tinyint         Sí       No
# APPR_ID                        bigint          Sí       No
# EPIS_ID                        bigint          Sí       No
# PATI_ID                        INT             Sí       No
# APPR_OBSERVATIONS              nvarchar        Sí       No
# APPE_DELETED                   bit             Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 216
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# APPE_ID                        0               0.00%
# APPE_REPETITIONS               56              25.93%
# APPE_FREQUENCY_NUMBER          0               0.00%
# FREQ_ID                        0               0.00%
# REIN_ID                        160             74.07%
# APPR_ID                        14              6.48%
# EPIS_ID                        216             100.00%
# PATI_ID                        0               0.00%
# APPR_OBSERVATIONS              188             87.04%
# APPE_DELETED                   0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    APPE_ID  APPE_REPETITIONS  APPE_FREQUENCY_NUMBER  FREQ_ID REIN_ID  APPR_ID  \
# 0       13                 1                      1        2    None      NaN
# 1       14                 1                      1        2    None  44703.0
# 2       30                 3                      1        2    None      NaN
# 3       35                 3                      1        2    None  44775.0
# 4       37                 7                      1        2    None  44778.0
#
#   EPIS_ID  PATI_ID APPR_OBSERVATIONS  APPE_DELETED                       MTIME
# 0    None     1721    Cita periódica             0  2000-11-30 23:30:55.123456
# 1    None     1721    Cita periódica             0  2000-11-30 23:30:55.123456
# 2    None     3370    Cita periódica             0  2000-11-30 23:30:55.123456
# 3    None     4153    Cita periódica             0  2000-11-30 23:30:55.123456
# 4    None     4524    Cita periódica             0  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: APPO_POSTPONED_REASONS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# PARE_ID                        INT             Sí       Sí
# PARE_DELETED                   bit             Sí       No
# PARE_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 2
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# PARE_ID                        0               0.00%
# PARE_DELETED                   0               0.00%
# PARE_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    PARE_ID  PARE_DELETED PARE_DESCRIPTION_ES                       MTIME
# 0        1             0     Motivos médicos  2000-11-30 23:30:55.123456
# 1        2             0   Demora voluntaria  2000-11-30 23:30:55.123456
#
# ================================================================================
# ...
# 2     1100     4197             0              ARTROGRAFÍA POR RM
# 3     1101     4192             0                          ABDOMEN
# 4     1102     4193             0  BIOPSIA ASISTIDA POR VACIO MAMA
#
#                         MTIME
# 0  2000-11-30 23:30:55.123456
# 1  2000-11-30 23:30:55.123456
# 2  2000-11-30 23:30:55.123456
# 3  2000-11-30 23:30:55.123456
# 4  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: TEST_TEST_TYPES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# TETY_ID                        smallint        Sí       Sí
# PPTY_ID                        tinyint         Sí       No
# TETY_DELETED                   bit             Sí       No
# TETY_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 590
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# TETY_ID                        0               0.00%
# PPTY_ID                        0               0.00%
# TETY_DELETED                   0               0.00%
# TETY_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    TETY_ID  PPTY_ID  TETY_DELETED                    TETY_DESCRIPTION_ES  \
# 0     4192        3             0                        RX CONVENCIONAL
# 1     4193        3             0              MAMOGRAFIA E INTERV. MAMA
# 2     4194        3             0  RADIOLOGÍA CONVENCIONAL CON CONTRASTE
# 3     4195        3             1      ESTUDIOS ESPECIFICOS DE PEDIATRÍA
# 4     4196        3             0                              ECOGRAFÍA
#
#                         MTIME
# 0  2000-11-30 23:30:55.123456
# 1  2000-11-30 23:30:55.123456
# 2  2000-11-30 23:30:55.123456
# 3  2000-11-30 23:30:55.123456
# 4  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: TIME_LINE_VIEW_TYPES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# TLVT_ID                        tinyint         Sí       Sí
# TLVT_DELETED                   bit             Sí       No
# TLVT_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 18
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# TLVT_ID                        0               0.00%
# TLVT_DELETED                   0               0.00%
# TLVT_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    TLVT_ID  TLVT_DELETED  TLVT_DESCRIPTION_ES                       MTIME
# 0        1             0          Laboratorio  2000-11-30 23:30:55.123456
# 1        2             0    Solicitud de Cita  2000-11-30 23:30:55.123456
# 2        3             0        Imagen Médica  2000-11-30 23:30:55.123456
# 3        4             0  Anatomía Patológica  2000-11-30 23:30:55.123456
# 4        5             0       Otras Técnicas  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: TRIA_REASONS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# TRRE_ID                        tinyint         Sí       Sí
# TRRE_DELETED                   bit             Sí       No
# TRRE_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 41
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# TRRE_ID                        0               0.00%
# TRRE_DELETED                   0               0.00%
# TRRE_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    TRRE_ID  TRRE_DELETED            TRRE_DESCRIPTION_ES  \
# 0        1             0                       Agresión
# 1        2             0     Alteración de la analítica
# 2        3             0   Alergias-Reacciones cutáneas
# 3        4             0      Alteración de Consciencia
# 4        5             0  Alteración del Comportamiento
#
#                         MTIME
# 0  2000-11-30 23:30:55.123456
# 1  2000-11-30 23:30:55.123456
# 2  2000-11-30 23:30:55.123456
# 3  2000-11-30 23:30:55.123456
# 4  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: TRIA_SYMPTOMS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# TRSY_ID                        smallint        Sí       Sí
# TRSY_ID_PARENT                 smallint        Sí       No
# TRSY_DESCRIPTION_ES            nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 152
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# TRSY_ID                        0               0.00%
# TRSY_ID_PARENT                 74              48.68%
# TRSY_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    TRSY_ID TRSY_ID_PARENT                 TRSY_DESCRIPTION_ES  \
# 0        1           None                Constantes alteradas
# 1        2           None           Estado Emocional alterado
# 2        3           None           Estado Emocional alterado
# 3        4           None                   Agitación extrema
# 4        5           None  Alteración súbita de estado mental
#
#                         MTIME
# 0  2000-11-30 23:30:55.123456
# 1  2000-11-30 23:30:55.123456
# 2  2000-11-30 23:30:55.123456
# 3  2000-11-30 23:30:55.123456
# 4  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: VACC_VACCINES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# VAVA_ID                        bigint          Sí       Sí
# PATI_ID                        INT             Sí       No
# VAVA_VACCINE                   nvarchar        Sí       No
# VAVA_DATE                      date            Sí       No
# VAVA_OBSERVATIONS              nvarchar        Sí       No
# VAVA_DOSE                      nvarchar        Sí       No
# VAVA_CENT_OTHER_DESC           nvarchar        Sí       No
# MTIME                          datetime2       Sí       No
#
# Número total de registros: 9
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# VAVA_ID                        0               0.00%
# PATI_ID                        0               0.00%
# VAVA_VACCINE                   0               0.00%
# VAVA_DATE                      0               0.00%
# VAVA_OBSERVATIONS              3               33.33%
# VAVA_DOSE                      0               0.00%
# VAVA_CENT_OTHER_DESC           9               100.00%
# MTIME                          0               0.00%
#
# Muestra de datos (primeras 5 filas):
#    VAVA_ID  PATI_ID              VAVA_VACCINE   VAVA_DATE  \
# 0      381     1161                  CHIROMAS  2020-10-21
# 1     1423     1445  PREVENAR 13-NEUMOCOCO 13  2021-03-24
# 2     1959     1445  BEXSERO (MENINGOCOCCO B)  2021-06-21
# 3     2143     1445  BEXSERO (MENINGOCOCCO B)  2021-07-19
# 4      369     2079          CJIROMAS (GRIPE)  2020-10-20
#
#                   VAVA_OBSERVATIONS VAVA_DOSE VAVA_CENT_OTHER_DESC  \
# 0                              None  1º DOSIS                 None
# 1   PACIENTE DE RIESGO CAD: 03/2023     UNICA                 None
# 2  PACIENTE DE RIESGO. CAD: 07/2022  1ª DOSIS                 None
# 3  PACIENTE DE RIESGO  CAD: 07/2022  2ª DOSIS                 None
# 4                 CAMPAÑA 2020-2021         1                 None
#
#                         MTIME
# 0  2000-11-30 23:30:55.123456
# 1  2000-11-30 23:30:55.123456
# 2  2000-11-30 23:30:55.123456
# 3  2000-11-30 23:30:55.123456
# 4  2000-11-30 23:30:55.123456
#
# ================================================================================
# ANÁLISIS DE TABLA: _METACOLS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# table_name                     nvarchar        Sí       No
# column_name                    nvarchar        Sí       No
# data_type                      nvarchar        Sí       No
# edit                           nvarchar        Sí       No
# samples                        nvarchar        Sí       No
#
# Número total de registros: 1638
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# table_name                     0               0.00%
# column_name                    0               0.00%
# data_type                      0               0.00%
# edit                           0               0.00%
# samples                        234             14.29%
#
# Muestra de datos (primeras 5 filas):
#                 table_name          column_name  data_type   edit  \
# 0  ACCI_PATIENT_CONDITIONS              APCO_ID    tinyint      *
# 1  ACCI_PATIENT_CONDITIONS         APCO_DELETED        bit      *
# 2  ACCI_PATIENT_CONDITIONS  APCO_DESCRIPTION_ES   nvarchar      *
# 3  ACCI_PATIENT_CONDITIONS                MTIME  datetime2  mtime
# 4       ACCI_VEHICLE_TYPES              VETY_ID    tinyint      *
#
#                                              samples
# 0                              1 | 2 | 3 | 4 | 5 | 6
# 1                                              False
# 2  Ciclista | Conductor | Motorista | Ocupante | ...
# 3                                               None
# 4                      1 | 2 | 3 | 4 | 5 | 6 | 7 | 8
#
# ================================================================================
# ANÁLISIS DE TABLA: _DICTIONARIES
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# COLUMN                         nvarchar        Sí       No
# KEY                            INT             Sí       No
# VAL                            nvarchar        Sí       No
#
# Número total de registros: 86003
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# COLUMN                         0               0.00%
# KEY                            0               0.00%
# VAL                            0               0.00%
#
# Muestra de datos (primeras 5 filas):
#     COLUMN  KEY        VAL
# 0  APCO_ID    1  Conductor
# 1  APCO_ID    2   Ocupante
# 2  APCO_ID    3     Peatón
# 3  APCO_ID    4   Ciclista
# 4  APCO_ID    5  Motorista
#
# ================================================================================
# ANÁLISIS DE TABLA: ONCO_EVENT_INDICATIONS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# EVIN_ID                        INTEGER         Sí       Sí
# EVIN_DELETED                   BIT             Sí       No
# EVIN_DESCRIPTION_ES            NVARCHAR        Sí       No
# MTIME                          DATETIME2       Sí       No
# PATI_ID                        INT             Sí       No
#
# Número total de registros: 4
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# EVIN_ID                        0               0.00%
# EVIN_DELETED                   0               0.00%
# EVIN_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
# PATI_ID                        4               100.00%
#
# Muestra de datos (primeras 5 filas):
#    EVIN_ID  EVIN_DELETED EVIN_DESCRIPTION_ES                       MTIME  \
# 0        1             0        Neoadyuvante  2000-11-30 23:30:55.123456
# 1        2             0           Adyuvante  2000-11-30 23:30:55.123456
# 2        3             0        Concomitante  2000-11-30 23:30:55.123456
# 3        4             0           Paliativo  2000-11-30 23:30:55.123456
#
#   PATI_ID
# 0    None
# 1    None
# 2    None
# 3    None
#
# Número total de registros: 86003
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# COLUMN                         0               0.00%
# KEY                            0               0.00%
# VAL                            0               0.00%
#
# Muestra de datos (primeras 5 filas):
#     COLUMN  KEY        VAL
# 0  APCO_ID    1  Conductor
# 1  APCO_ID    2   Ocupante
# 2  APCO_ID    3     Peatón
# 3  APCO_ID    4   Ciclista
# 4  APCO_ID    5  Motorista
#
# ================================================================================
# ANÁLISIS DE TABLA: ONCO_EVENT_INDICATIONS
# ================================================================================
# Estructura de la tabla:
# Columna                        Tipo            Nullable PK
# ------------------------------ --------------- -------- -----
# EVIN_ID                        INTEGER         Sí       Sí
# EVIN_DELETED                   BIT             Sí       No
# EVIN_DESCRIPTION_ES            NVARCHAR        Sí       No
# MTIME                          DATETIME2       Sí       No
# PATI_ID                        INT             Sí       No
#
# Número total de registros: 4
#
# Estadísticas de valores NULL:
# Columna                        Total NULLs     % NULLs
# ------------------------------ --------------- ----------
# EVIN_ID                        0               0.00%
# EVIN_DELETED                   0               0.00%
# EVIN_DESCRIPTION_ES            0               0.00%
# MTIME                          0               0.00%
# PATI_ID                        4               100.00%
#
# Muestra de datos (primeras 5 filas):
#    EVIN_ID  EVIN_DELETED EVIN_DESCRIPTION_ES                       MTIME  \
# 0        1             0        Neoadyuvante  2000-11-30 23:30:55.123456
# 1        2             0           Adyuvante  2000-11-30 23:30:55.123456
# 2        3             0        Concomitante  2000-11-30 23:30:55.123456
# 3        4             0           Paliativo  2000-11-30 23:30:55.123456
#
#   PATI_ID
# 0    None
# 1    None
# 2    None
# 3    None

# %% [markdown]
# ## Resumen del Análisis
#
# Basándonos en los resultados anteriores, podemos resumir:
#
# 1. **Estado general de la base de datos**
#    - Número total de tablas
#    - Tablas completamente vacías
#    - Tablas que contienen solo valores NULL
#
# 2. **Recomendaciones**
#    - Si hay tablas vacías, podrían eliminarse o poblarse con datos relevantes
#    - Si hay un alto porcentaje de valores NULL, considerar rediseñar el esquema o poblar esos campos

# %%
# Crear un resumen general
print("RESUMEN DE ANÁLISIS DE LA BASE DE DATOS")
print("="*40)

# Contar tablas vacías y con solo valores NULL
empty_tables = []
null_only_tables = []

for table in tables:
    table_name = table[0]
    
    # Verificar si está vacía
    cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
    count = cursor.fetchone()[0]
    
    if count == 0:
        empty_tables.append(table_name)
        continue
    
    # Verificar si solo tiene valores NULL
    try:
        df = pd.read_sql_query(f"SELECT * FROM {table_name} LIMIT 100", conn)
        if df.isnull().all().all():
            null_only_tables.append(table_name)
    except:
        pass

print(f"Total de tablas: {len(tables)}")
print(f"Tablas vacías: {len(empty_tables)}")
if empty_tables:
    print(f"  - " + "\n  - ".join(empty_tables))
    
print(f"Tablas con solo valores NULL: {len(null_only_tables)}")
if null_only_tables:
    print(f"  - " + "\n  - ".join(null_only_tables))

# Cerrar conexión
conn.close()
print("\nConexión cerrada.")
# Out:
# RESUMEN DE ANÁLISIS DE LA BASE DE DATOS
# ========================================
# Total de tablas: 236
# Tablas vacías: 7
#   - HEAL_DIABETES_INDICATORS
#   - HEAL_HYPERTENS_INDICATORS
#   - HIST_ANDROLOGICALS
#   - HIST_PEDIATRICS
#   - HIST_SOCIOECONOMICS
#   - ONCO_CANCERS
#   - ONCO_FAMILIAR_HISTORY
# Tablas con solo valores NULL: 0
#
# Conexión cerrada.
# Total de tablas: 236
# Tablas vacías: 7
#   - HEAL_DIABETES_INDICATORS
#   - HEAL_HYPERTENS_INDICATORS
#   - HIST_ANDROLOGICALS
#   - HIST_PEDIATRICS
#   - HIST_SOCIOECONOMICS
#   - ONCO_CANCERS
#   - ONCO_FAMILIAR_HISTORY
# Tablas con solo valores NULL: 0
#
# Conexión cerrada.

# %% [markdown]
# ## Conclusiones
#
# Basado en nuestro análisis:
#
# 1. **Si encontramos tablas vacías o con solo valores NULL:**
#    - Esto podría indicar que la base de datos no está correctamente inicializada
#    - Puede ser necesario cargar datos de ejemplo o reales antes de continuar con el análisis
#    - Es posible que la estructura esté definida pero faltan datos para poblarla
#
# 2. **Próximos pasos recomendados:**
#    - Verificar el proceso de carga de datos
#    - Revisar si hay scripts de inicialización que no se han ejecutado
#    - Confirmar que la ruta de la base de datos es la correcta (podría estar apuntando a una versión vacía)

# %% [markdown]
# ## Información Adicional para Mejorar el Análisis
#
# El análisis anterior proporciona ahora información más detallada sobre:
#
# 1. **Estadísticas numéricas** para columnas con datos numéricos
#    - Mínimo, máximo, media, mediana
#    - Distribución de valores más comunes
#
# 2. **Análisis de texto** para columnas tipo string/objeto
#    - Conteo de valores únicos
#    - Valores más frecuentes
#    - Longitud media de textos
#
# 3. **Análisis temporal** para columnas de fecha/hora
#    - Rango de fechas (más antigua a más reciente)
#    - Distribución por año cuando aplica
#
# 4. **Detección de relaciones** entre tablas
#    - Identificación de posibles claves foráneas
#    - Valores comunes en estas relaciones
#
# Cada tabla ahora mostrará información más detallada para entender mejor la estructura y contenido de los datos, lo que facilita identificar posibles problemas o patrones interesantes.

# %% [markdown]
# # Análisis de Resultados
#
# ## Resumen de hallazgos principales
#
# Después de analizar la base de datos `database_new.sqlite3.db`, podemos concluir:
#
# 1. **Estructura general**:
#    - La base de datos contiene 236 tablas en total
#    - Es un esquema amplio que sugiere un sistema de información médica complejo
#
# 2. **Estado de los datos**:
#    - La mayoría de las tablas (229 de 236, o 97%) contienen datos
#    - 7 tablas están completamente vacías (sin registros)
#    - No se encontraron tablas con registros que contengan solo valores NULL
#
# 3. **Tablas vacías**: Todas las tablas vacías parecen estar relacionadas con áreas médicas específicas:
#    - Indicadores de salud: diabetes e hipertensión
#    - Historiales médicos especializados: andrológicos, pediátricos y socioeconómicos
#    - Información oncológica: registros de cánceres e historiales familiares
#
# ## ¿Faltan datos?
#
# **Respuesta**: Sí, pero de forma limitada y en áreas específicas.
#
# La base de datos está predominantemente poblada (97% de las tablas tienen datos). Las tablas que están vacías parecen pertenecer a módulos o funcionalidades específicas del sistema, posiblemente:
#
# - Módulos que aún no han sido implementados
# - Funcionalidades planificadas pero no utilizadas actualmente
# - Áreas donde no se han migrado o importado los datos correspondientes
#
# ## Recomendaciones
#
# 1. **Para las tablas vacías**:
#    - Verificar si estas áreas son realmente necesarias para la funcionalidad actual del sistema
#    - Si son necesarias, priorizar la carga de datos para estas tablas específicas
#    - Considerar la eliminación de tablas que no se utilizarán en el futuro previsible
#
# 2. **Completitud de datos**:
#    - La base de datos parece tener suficientes datos para ser funcional
#    - Se recomienda realizar un análisis de calidad más profundo en las tablas principales para verificar la integridad referencial
#
# 3. **Próximos pasos**:
#    - Identificar las tablas principales del sistema y verificar la calidad e integridad de sus datos
#    - Examinar las relaciones entre tablas para asegurar que las referencias son válidas
#    - Desarrollar un plan para poblar las tablas vacías si son relevantes para la funcionalidad del sistema

# %%
# Analizar las relaciones entre tablas para verificar integridad referencial
# Específicamente para las tablas relacionadas con las áreas vacías

try:
    # Reconexión a la base de datos ya que cerramos la conexión anteriormente
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # Lista de prefijos de las tablas vacías
    empty_prefixes = ['HEAL_', 'HIST_', 'ONCO_']
    
    print("ANÁLISIS DE RELACIONES PARA TABLAS VACÍAS")
    print("=" * 50)
    
    # Buscar tablas relacionadas que SÍ contengan datos
    related_tables = []
    
    for prefix in empty_prefixes:
        # Encontrar todas las tablas con este prefijo
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name LIKE ?", (f"{prefix}%",))
        prefix_tables = [row[0] for row in cursor.fetchall()]
        
        print(f"\nAnálisis para prefijo: {prefix}")
        print(f"Tablas con este prefijo: {len(prefix_tables)}")
        
        # Verificar cuáles tienen datos y cuáles no
        tables_with_data = []
        tables_without_data = []
        
        for table in prefix_tables:
            cursor.execute(f"SELECT COUNT(*) FROM {table}")
            count = cursor.fetchone()[0]
            
            if count > 0:
                tables_with_data.append((table, count))
            else:
                tables_without_data.append(table)
        
        print(f"- Tablas con datos: {len(tables_with_data)}")
        for table, count in tables_with_data:
            print(f"  * {table}: {count} registros")
            
        print(f"- Tablas vacías: {len(tables_without_data)}")
        for table in tables_without_data:
            print(f"  * {table}")
    
    # Cerrar la conexión
    conn.close()
    print("\nAnálisis completado.")
    
except Exception as e:
    print(f"Error durante el análisis de relaciones: {e}")

# %% [markdown]
# ## Conclusión sobre la falta de datos
#
# Basado en el análisis completo, podemos concluir:
#
# 1. **Estado general**: La base de datos está bien poblada en su mayor parte, con solo 7 tablas vacías de un total de 236.
#
# 2. **Naturaleza de las tablas vacías**: Las tablas vacías pertenecen a módulos específicos relacionados con:
#    - Datos clínicos especializados (diabetes, hipertensión)
#    - Historiales médicos específicos (andrología, pediatría)
#    - Información oncológica
#
# 3. **Impacto en el sistema**:
#    - Si estas tablas representan funcionalidades secundarias o complementarias, su ausencia probablemente no afecte la operación principal del sistema
#    - Si son centrales para algunas funcionalidades específicas, esas características no serán utilizables
#
# 4. **Recomendación final**:
#    - La base de datos parece ser funcional para la mayoría de los propósitos
#    - Las áreas vacías probablemente representan módulos que aún no están en uso activo
#    - Se recomienda priorizar la población de estas tablas solo si son necesarias para los casos de uso actuales o próximos del sistema
